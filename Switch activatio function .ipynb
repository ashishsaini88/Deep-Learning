# %%
import pandas as pd
import numpy as np 
import tensorflow as tf

from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation 
from tensorflow.keras import backend as k

# %%
df = pd.read_csv(r"C:\Users\KOIN\Downloads\titanic (1).csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df["Age"].fillna(df["Age"].median() , inplace=True)
df["Fare"].fillna(df["Fare"].median() , inplace=True)
df["Embarked"].fillna(df["Embarked"].mode() , inplace=True)

df["Sex"] = df["Sex"].map({"male" : 1 , "female" : 0})

features = ["Pclass" , "Age" , "Fare" , "Sex"]
x = df[features]

y = df["Survived"]
# Out:
# C:\Users\KOIN\AppData\Local\Temp\ipykernel_5352\484437843.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median() , inplace=True)
# C:\Users\KOIN\AppData\Local\Temp\ipykernel_5352\484437843.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fare"].fillna(df["Fare"].median() , inplace=True)
# C:\Users\KOIN\AppData\Local\Temp\ipykernel_5352\484437843.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna(df["Embarked"].mode() , inplace=True)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2 , random_state=42)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
def switch_activation(x):
    return x * tf.keras.activations.sigmoid(x)

# %%
model = Sequential()

# %%
model.add(Dense(32 , input_dim= x_train_scaled.shape[1]))
model.add(Activation(switch_activation))

model.add(Dense(16))
model.add(Activation(switch_activation))

model.add(Dense (1 , activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy" , optimizer="adam" , metrics=["accuracy"])

# %%
model.fit(x_train_scaled , y_train , epochs=50 , batch_size=32 , validation_split=0.2)


loss , accuracy = model.evaluate(x_test_scaled , y_test)

print(f"Model accuracy : {accuracy * 100:.2f} %")
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.3063e-04 - val_accuracy: 1.0000 - val_loss: 2.3896e-04
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.2720e-04 - val_accuracy: 1.0000 - val_loss: 2.3536e-04
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.2383e-04 - val_accuracy: 1.0000 - val_loss: 2.3191e-04
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.2058e-04 - val_accuracy: 1.0000 - val_loss: 2.2855e-04
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.1740e-04 - val_accuracy: 1.0000 - val_loss: 2.2522e-04
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.1425e-04 - val_accuracy: 1.0000 - val_loss: 2.2200e-04
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.1124e-04 - val_accuracy: 1.0000 - val_loss: 2.1875e-04
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.0814e-04 - val_accuracy: 1.0000 - val_loss: 2.1564e-04
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.0517e-04 - val_accuracy: 1.0000 - val_loss: 2.1258e-04
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.0223e-04 - val_accuracy: 1.0000 - val_loss: 2.0958e-04
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9938e-04 - val_accuracy: 1.0000 - val_loss: 2.0661e-04
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.9657e-04 - val_accuracy: 1.0000 - val_loss: 2.0366e-04
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9379e-04 - val_accuracy: 1.0000 - val_loss: 2.0076e-04
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9107e-04 - val_accuracy: 1.0000 - val_loss: 1.9796e-04
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.8846e-04 - val_accuracy: 1.0000 - val_loss: 1.9525e-04
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.8586e-04 - val_accuracy: 1.0000 - val_loss: 1.9257e-04
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.8330e-04 - val_accuracy: 1.0000 - val_loss: 1.8993e-04
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.8080e-04 - val_accuracy: 1.0000 - val_loss: 1.8736e-04
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.7841e-04 - val_accuracy: 1.0000 - val_loss: 1.8482e-04
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.7600e-04 - val_accuracy: 1.0000 - val_loss: 1.8236e-04
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.7370e-04 - val_accuracy: 1.0000 - val_loss: 1.7994e-04
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.7142e-04 - val_accuracy: 1.0000 - val_loss: 1.7754e-04
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.6914e-04 - val_accuracy: 1.0000 - val_loss: 1.7520e-04
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.6691e-04 - val_accuracy: 1.0000 - val_loss: 1.7292e-04
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.6472e-04 - val_accuracy: 1.0000 - val_loss: 1.7068e-04
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.6257e-04 - val_accuracy: 1.0000 - val_loss: 1.6845e-04
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.6045e-04 - val_accuracy: 1.0000 - val_loss: 1.6627e-04
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5838e-04 - val_accuracy: 1.0000 - val_loss: 1.6413e-04
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5637e-04 - val_accuracy: 1.0000 - val_loss: 1.6201e-04
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5438e-04 - val_accuracy: 1.0000 - val_loss: 1.5990e-04
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5240e-04 - val_accuracy: 1.0000 - val_loss: 1.5788e-04
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5049e-04 - val_accuracy: 1.0000 - val_loss: 1.5592e-04
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.4860e-04 - val_accuracy: 1.0000 - val_loss: 1.5398e-04
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.4679e-04 - val_accuracy: 1.0000 - val_loss: 1.5207e-04
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4497e-04 - val_accuracy: 1.0000 - val_loss: 1.5019e-04
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4318e-04 - val_accuracy: 1.0000 - val_loss: 1.4836e-04
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4144e-04 - val_accuracy: 1.0000 - val_loss: 1.4656e-04
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3970e-04 - val_accuracy: 1.0000 - val_loss: 1.4480e-04
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3804e-04 - val_accuracy: 1.0000 - val_loss: 1.4302e-04
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3636e-04 - val_accuracy: 1.0000 - val_loss: 1.4129e-04
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3475e-04 - val_accuracy: 1.0000 - val_loss: 1.3959e-04
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3312e-04 - val_accuracy: 1.0000 - val_loss: 1.3790e-04
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3154e-04 - val_accuracy: 1.0000 - val_loss: 1.3624e-04
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2996e-04 - val_accuracy: 1.0000 - val_loss: 1.3462e-04
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2842e-04 - val_accuracy: 1.0000 - val_loss: 1.3302e-04
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2690e-04 - val_accuracy: 1.0000 - val_loss: 1.3145e-04
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2541e-04 - val_accuracy: 1.0000 - val_loss: 1.2988e-04
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2395e-04 - val_accuracy: 1.0000 - val_loss: 1.2833e-04
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2249e-04 - val_accuracy: 1.0000 - val_loss: 1.2683e-04
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.2105e-04 - val_accuracy: 1.0000 - val_loss: 1.2538e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.2693e-04
# Model accuracy : 100.00 %
